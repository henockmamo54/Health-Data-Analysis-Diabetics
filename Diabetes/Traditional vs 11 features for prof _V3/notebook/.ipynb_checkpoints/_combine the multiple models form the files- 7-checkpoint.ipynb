# %%
import pandas as pd
import numpy as np
import warnings
from matplotlib import pyplot as plt
from sklearn import metrics as m
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE  # doctest: +NORMALIZE_WHITESPACE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
from sklearn.metrics import classification_report
import xgboost as xgb
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.classifier import StackingClassifier
import itertools
from sklearn.pipeline import make_pipeline
from mlxtend.feature_selection import ColumnSelector
from mlxtend.classifier import StackingCVClassifier



warnings.filterwarnings("ignore")
randomseed = 7
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 1.Read the dataset and preprocess
# ======

# %%
x_original = pd.read_csv("../../XLable_onlyDiabeticRemoved.txt")

conditions = [
    (x_original.L100800 < 100),
    (x_original.L100800 >= 100) & (x_original.L100800 < 126),
    (x_original.L100800 >= 126),
]
choices = [0, 1, 2]
x_original["CLASS"] = np.select(conditions, choices, default=0)
x_original=x_original [['Unnamed: 0','L100800','L104600','L103000','S000300','L101700','L100700','FIELD_33',
                       'FIELD_38','FIELD_40','FIELD_31','SEX','AGE',#'CLASS',
                       'FIELD_16','FIELD_23','FIELD_15','FIELD_22','FIELD_17','FIELD_24'
                       ]]

# %%
y_original = pd.read_csv("../../TargetLable_onlyDiabeticRemoved.txt")

conditions = [
    (y_original.L100800 < 100),
    (y_original.L100800 >= 100) & (y_original.L100800 < 126),
    (y_original.L100800 >= 126),
]

choices = [0, 1, 2]
y_original["CLASS"] = np.select(conditions, choices, default=0)

y_original=y_original[['Unnamed: 0','CLASS' ]]

# %%
data = pd.merge(
    x_original, y_original, how="inner", left_on="Unnamed: 0", right_on="Unnamed: 0"
)

# %%
# filter the data set
data = data[data.FIELD_16 != 1]  # exclude people who are diagnosed for (diabetes)
data = data[data.FIELD_23 != 1]  # exclude people who are on medication for diabetes

data = data[
    data.FIELD_15 != 1
]  # exclude people who are diagnosed for (high blood pressure)
data = data[
    data.FIELD_22 != 1
]  # exclude people who are on medication for high blood pressure

data = data[data.FIELD_17 != 1]  # exclude people who are diagnosed for hyperlipidemia
data = data[
    data.FIELD_24 != 1
]  # exclude people who are on medication for hyperlipidemia


print(data.shape)
# Out:
# (169024, 20)

# %%
data=data[['L100800','L104600', 'L103000', 'S000300', 'L101700', 'L100700',
       'FIELD_33', 'FIELD_38', 'FIELD_40', 'FIELD_31', 'SEX', 'AGE','CLASS']]
data=data.dropna()
print(data.shape)
data.head()
# Out:
# (56542, 13)
#     L100800  L104600  L103000  S000300  L101700  L100700  FIELD_33  FIELD_38  \
# 2      78.0     5.28     41.0     20.2     15.0      3.8       1.0       2.0
# 5      90.0     5.74     50.0     25.5     12.0      3.4       1.0       0.0
# 10     86.0     5.83     45.0     21.2     17.0      3.9       1.0       0.0
# 11     86.0     4.73     54.0     22.0     30.0      4.2       1.0       2.0
# 20     87.0     5.60    340.0     24.6     26.0      4.7       1.0       0.0
#
#     FIELD_40  FIELD_31  SEX   AGE  CLASS
# 2        1.0       0.0  1.0  46.0      0
# 5        1.0       0.0  1.0  52.0      0
# 10       1.0       1.0  1.0  37.0      0
# 11       3.0       0.0  1.0  39.0      0
# 20       2.0       0.0  1.0  59.0      0

# %% [markdown]
# 2.Downsample the majority class and upsample the minority
# ====

# %%
diabetic = data[data.CLASS == 2]
prediabetic = data[data.CLASS == 1]
normal = data[data.CLASS == 0]

print(diabetic.shape[0], prediabetic.shape[0], normal.shape[0])
# Out:
# 1045 17331 38166

# %%
diabetic_test = diabetic.sample(200, random_state=randomseed)
prediabetic_test = prediabetic.sample(200, random_state=randomseed)
normal_test = normal.sample(200, random_state=randomseed)
test = pd.concat([diabetic_test, prediabetic_test, normal_test])

diabetic_train = diabetic.drop(diabetic_test.index)
prediabetic_train = prediabetic.drop(prediabetic_test.index)
# .sample(
#     10 * diabetic_train.shape[0], random_state=randomseed
# )
normal_train = normal.drop(normal_test.index).sample(
    prediabetic_train.shape[0],random_state=randomseed
#     10 * diabetic_train.shape[0], random_state=randomseed
)
train = pd.concat([diabetic_train, diabetic_train, prediabetic_train, normal_train])

# %%
xtrain = train.iloc[:, :-1]
ytrain = train.iloc[:, -1]
xtest = test.iloc[:, :-1]
ytest = test.iloc[:, -1]

# %%
from sklearn.preprocessing import MinMaxScaler 
scaler = MinMaxScaler()
xtrain=scaler.fit_transform(xtrain)
xtest=scaler.transform(xtest)

# %%
from imblearn.over_sampling import SMOTE,SMOTENC  # doctest: +NORMALIZE_WHITESPACE
randomseed=42

sm = SMOTENC(random_state=randomseed,categorical_features=[6,7,8,9,10],sampling_strategy='minority')
X_res, y_res = sm.fit_resample(xtrain, ytrain)

print("Resampled dataset shape %s" % Counter(y_res))
print(
    y_res[y_res == 0].shape[0], y_res[y_res == 1].shape[0], y_res[y_res == 2].shape[0]
)
print(X_res.shape, y_res.shape)

xtrain = X_res
ytrain = y_res
# Out:
# Resampled dataset shape Counter({2: 17131, 1: 17131, 0: 17131})
# 17131 17131 17131
# (51393, 12) (51393,)

# %% [markdown]
# 3.Generate the classifier models based on the selected 12 features
# ====

# %%
# #rf
# rf_12 = RandomForestClassifier(
#     random_state=randomseed,
#     n_estimators=100, 
#     max_depth=12,
#     min_samples_split=3,
#     min_samples_leaf=10,
#     max_features="auto",
# )

# %%
# #xgboost
# xgb_model_12 = xgb.XGBClassifier(objective="binary:logistic", random_state=randomseed)

# %%
# #svm
# SVC_clf_12=SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# #lr
# lr_12=LogisticRegression(random_state=0)

# %%
# #knn
# kneigh_12 = KNeighborsClassifier(n_neighbors=150)

# %%
# #stacking classfier

# lr2_12 = LogisticRegression()
# temprf_12=RandomForestClassifier(n_estimators=500, random_state=42)
# temprf2_12=RandomForestClassifier()
# tempsvC_12= SVC()

# estimators_12 = [
#     rf_12,
#     xgb_model_12,
#     SVC_clf_12,
#     lr_12,
#     kneigh_12
# ]
# stackingc_12 = StackingClassifier(
#     classifiers=estimators_12,
#     meta_classifier=tempsvC_12,
#     verbose=2 
# )

# %%
# stackingc_12.fit(xtrain,ytrain)

# %%
# y_pred = stackingc_12.predict((xtest))

# print("accuracy \t", m.accuracy_score(ytest, y_pred))
# confmatrx = pd.DataFrame(m.confusion_matrix(ytest, y_pred))
# confmatrx.head()

# %% [markdown]
# 4.Generate the classifier models based on the selected 5 features
# ===

# %%
# rf_5 = RandomForestClassifier(
#     random_state=randomseed,
#     n_estimators=100, 
#     max_depth=12,
#     min_samples_split=3,
#     min_samples_leaf=10,
#     max_features="auto",
# )

# %%
xgb_model_5 = xgb.XGBClassifier(objective="multi:softmax", random_state=randomseed)

# %%
# SVC_clf_5=SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# lr_5=LogisticRegression(random_state=0)

# %%
# kneigh_5 = KNeighborsClassifier(n_neighbors=150)

# %%
# lr2_5 = LogisticRegression()
# temprf_5=RandomForestClassifier(n_estimators=500, random_state=42)
# temprf2_5=RandomForestClassifier()
# tempsvC_5= SVC()

# estimators_5 = [
#     rf_5,
#     xgb_model_5,
#     SVC_clf_5,
#     lr_5,
#     kneigh_5
# ]
# stackingc_5 = StackingClassifier(
#     classifiers=estimators_5, 
#     meta_classifier=tempsvC_5,
#     verbose=2 
# )

# %%
# stackingc_5.fit(xtrain,ytrain)

# %%
# y_pred = stackingc_5.predict((xtest))

# print("accuracy \t", m.accuracy_score(ytest, y_pred))
# confmatrx = pd.DataFrame(m.confusion_matrix(ytest, y_pred))
# confmatrx.head()

# %%
# print(classification_report(ytest, y_pred))

# %%
# y_pred=stackingc_5.clfs_[2].predict((xtest))
# print("accuracy \t", m.accuracy_score(ytest, y_pred))
# confmatrx = pd.DataFrame(m.confusion_matrix(ytest, y_pred))
# confmatrx.head()

# %% [markdown]
# 5.Generate multiple weak models using the existing features
# ====

# %%
from itertools import combinations
combcols=(list(combinations(np.arange(0,12,1), 7)))
len(combcols)
# Out:
# 792

# %%
weakmodles=[]

# %%
for i in range(len(combcols)):
#     print(combcols[i])
    weakmodles.append(make_pipeline(ColumnSelector(cols=combcols[i]), xgb_model_5 ))

# %%
sclf1 = StackingCVClassifier(classifiers=weakmodles,verbose=2,
                           meta_classifier=LogisticRegression(),random_state=42)

# %%
sclf1.fit(xtrain,ytrain)
# Out:
# Fitting 792 classifiers...
# Fitting classifier1: pipeline (1/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 6), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier2: pipeline (2/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 7), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier3: pipeline (3/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier4: pipeline (4/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier5: pipeline (5/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier6: pipeline (6/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier7: pipeline (7/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 6, 7), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier8: pipeline (8/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 6, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier9: pipeline (9/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 6, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier10: pipeline (10/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 6, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier11: pipeline (11/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 6, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier12: pipeline (12/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 7, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier13: pipeline (13/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 7, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier14: pipeline (14/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 7, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier15: pipeline (15/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 7, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier16: pipeline (16/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 8, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier17: pipeline (17/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 8, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier18: pipeline (18/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 8, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier19: pipeline (19/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 9, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier20: pipeline (20/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 9, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier21: pipeline (21/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier22: pipeline (22/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 6, 7), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier23: pipeline (23/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 6, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier24: pipeline (24/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 6, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier25: pipeline (25/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 6, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier26: pipeline (26/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 6, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier27: pipeline (27/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 7, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier28: pipeline (28/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 7, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier29: pipeline (29/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 7, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier30: pipeline (30/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 7, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier31: pipeline (31/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 8, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier32: pipeline (32/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 8, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier33: pipeline (33/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 8, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier34: pipeline (34/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 9, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier35: pipeline (35/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 9, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier36: pipeline (36/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 5, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier37: pipeline (37/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 6, 7, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier38: pipeline (38/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 6, 7, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier39: pipeline (39/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 6, 7, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier40: pipeline (40/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 6, 7, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier41: pipeline (41/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 6, 8, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier42: pipeline (42/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 6, 8, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
# ...
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier782: pipeline (782/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(3, 5, 6, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier783: pipeline (783/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(3, 5, 7, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier784: pipeline (784/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(3, 6, 7, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier785: pipeline (785/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 5, 6, 7, 8, 9, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier786: pipeline (786/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 5, 6, 7, 8, 9, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier787: pipeline (787/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 5, 6, 7, 8, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier788: pipeline (788/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 5, 6, 7, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier789: pipeline (789/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 5, 6, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier790: pipeline (790/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 5, 7, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier791: pipeline (791/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(4, 6, 7, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier792: pipeline (792/792)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(5, 6, 7, 8, 9, 10, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s finished
# StackingCVClassifier(classifiers=[Pipeline(memory=None,
#                                            steps=[('columnselector',
#                                                    ColumnSelector(cols=(0, 1, 2,
#                                                                         3, 4, 5,
#                                                                         6),
#                                                                   drop_axis=False)),
#                                                   ('xgbclassifier',
#                                                    XGBClassifier(base_score=0.5,
#                                                                  booster='gbtree',
#                                                                  colsample_bylevel=1,
#                                                                  colsample_bynode=1,
#                                                                  colsample_bytree=1,
#                                                                  gamma=0,
#                                                                  learning_rate=0.1,
#                                                                  max_delta_step=0,
#                                                                  max_depth=3,
#                                                                  min_child_weight=1,
#                                                                  missing=None,
#                                                                  n_estima...
#                                                         fit_intercept=True,
#                                                         intercept_scaling=1,
#                                                         l1_ratio=None,
#                                                         max_iter=100,
#                                                         multi_class='warn',
#                                                         n_jobs=None,
#                                                         penalty='l2',
#                                                         random_state=None,
#                                                         solver='warn',
#                                                         tol=0.0001, verbose=0,
#                                                         warm_start=False),
#                      n_jobs=None, pre_dispatch='2*n_jobs', random_state=42,
#                      shuffle=True, store_train_meta_features=False,
#                      stratify=True, use_clones=True,
#                      use_features_in_secondary=False, use_probas=False,
#                      verbose=2)

# %%
y_pred = sclf1.predict((xtest))

print("accuracy \t", m.accuracy_score(ytest, y_pred))
confmatrx = pd.DataFrame(m.confusion_matrix(ytest, y_pred))
confmatrx.head()
# Out:
# accuracy 	 0.705
#      0   1    2
# 0  153  45    2
# 1   71  97   32
# 2    5  22  173

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(sclf,
                         xtrain,ytrain,
                         cv=5,
                         scoring='accuracy')

# %%
len(sclf1.clfs_)
# Out:
# 792

# %%
accuracy=[]
for i in range(len(sclf1.clfs_)):
    model=sclf1.clfs_[i]
    y_pred = model.predict((xtest))
    accuracy.append(m.accuracy_score(ytest, y_pred))
#     print(i)

# %%
accuracypd= pd.DataFrame()
accuracypd['accuracy']=accuracy
accuracypd['index']=np.arange(0,len(accuracy),1)
accuracypd['cols']=combcols
accuracypd.head()
# Out:
#    accuracy  index                    cols
# 0  0.726667      0   (0, 1, 2, 3, 4, 5, 6)
# 1  0.720000      1   (0, 1, 2, 3, 4, 5, 7)
# 2  0.731667      2   (0, 1, 2, 3, 4, 5, 8)
# 3  0.725000      3   (0, 1, 2, 3, 4, 5, 9)
# 4  0.733333      4  (0, 1, 2, 3, 4, 5, 10)

# %%
selectedclassifiers_info=accuracypd[accuracypd.accuracy>0.73].sort_values(by='accuracy',ascending=False).reset_index()
selectedclassifiers_info.head(10)
# Out:
#    level_0  accuracy  index                     cols
# 0      170  0.750000    170  (0, 1, 3, 5, 6, 10, 11)
# 1      140  0.750000    140  (0, 1, 3, 4, 5, 10, 11)
# 2       20  0.750000     20  (0, 1, 2, 3, 4, 10, 11)
# 3       35  0.750000     35  (0, 1, 2, 3, 5, 10, 11)
# 4      189  0.748333    189  (0, 1, 3, 6, 8, 10, 11)
# 5      250  0.748333    250  (0, 1, 6, 8, 9, 10, 11)
# 6      246  0.748333    246   (0, 1, 6, 7, 8, 9, 10)
# 7       54  0.748333     54  (0, 1, 2, 3, 8, 10, 11)
# 8      119  0.748333    119  (0, 1, 2, 6, 8, 10, 11)
# 9      195  0.746667    195  (0, 1, 3, 8, 9, 10, 11)

# %%
selectedclassifiers_index=selectedclassifiers_info.index
selectedclassifiers_index
# Out:
# RangeIndex(start=0, stop=213, step=1)

# %%
print(list(selectedclassifiers_info.cols[:10]))
# Out:
# [(0, 1, 3, 5, 6, 10, 11), (0, 1, 3, 4, 5, 10, 11), (0, 1, 2, 3, 4, 10, 11), (0, 1, 2, 3, 5, 10, 11), (0, 1, 3, 6, 8, 10, 11), (0, 1, 6, 8, 9, 10, 11), (0, 1, 6, 7, 8, 9, 10), (0, 1, 2, 3, 8, 10, 11), (0, 1, 2, 6, 8, 10, 11), (0, 1, 3, 8, 9, 10, 11)]

# %% [markdown]
# 6.Use only selected classifier from the previous model which have >73% accuracy
# ===

# %%
weakmodles2=[]

# %%
# for i in range(len(selectedclassifiers_index)):
for i in range(10):
#     print(combcols[i])
    weakmodles2.append(make_pipeline(ColumnSelector(cols=selectedclassifiers_info.cols[i]), xgb_model_5 ))

# %%
sclf2 = StackingCVClassifier(classifiers=weakmodles2,verbose=2,
                           meta_classifier=xgb.XGBClassifier(objective="multi:softmax", random_state=randomseed),
#                              LogisticRegression(),
                             random_state=42)

# %%
sclf2.fit(xtrain,ytrain)
# Out:
# Fitting 10 classifiers...
# Fitting classifier1: pipeline (1/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 3, 4, 5, 8, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier2: pipeline (2/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 4, 5, 7, 9, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier3: pipeline (3/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 3, 4, 5, 6, 8), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier4: pipeline (4/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier5: pipeline (5/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 4, 5, 8, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier6: pipeline (6/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 3, 4, 5, 7, 9), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier7: pipeline (7/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 4, 5, 7, 9, 10), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier8: pipeline (8/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 3, 4, 5, 6, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier9: pipeline (9/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 2, 3, 4, 5, 7), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting classifier10: pipeline (10/10)
# Pipeline(memory=None,
#          steps=[('columnselector',
#                  ColumnSelector(cols=(0, 1, 3, 4, 5, 9, 11), drop_axis=False)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='multi:softmax', random_state=42,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s finished
# StackingCVClassifier(classifiers=[Pipeline(memory=None,
#                                            steps=[('columnselector',
#                                                    ColumnSelector(cols=(0, 1, 3,
#                                                                         4, 5, 8,
#                                                                         9),
#                                                                   drop_axis=False)),
#                                                   ('xgbclassifier',
#                                                    XGBClassifier(base_score=0.5,
#                                                                  booster='gbtree',
#                                                                  colsample_bylevel=1,
#                                                                  colsample_bynode=1,
#                                                                  colsample_bytree=1,
#                                                                  gamma=0,
#                                                                  learning_rate=0.1,
#                                                                  max_delta_step=0,
#                                                                  max_depth=3,
#                                                                  min_child_weight=1,
#                                                                  missing=None,
#                                                                  n_estima...
#                                                    n_estimators=100, n_jobs=1,
#                                                    nthread=None,
#                                                    objective='multi:softmax',
#                                                    random_state=42, reg_alpha=0,
#                                                    reg_lambda=1,
#                                                    scale_pos_weight=1,
#                                                    seed=None, silent=None,
#                                                    subsample=1, verbosity=1),
#                      n_jobs=None, pre_dispatch='2*n_jobs', random_state=42,
#                      shuffle=True, store_train_meta_features=False,
#                      stratify=True, use_clones=True,
#                      use_features_in_secondary=False, use_probas=False,
#                      verbose=2)

# %%
y_pred = sclf2.predict((xtest))

print("accuracy \t", m.accuracy_score(ytest, y_pred))
confmatrx = pd.DataFrame(m.confusion_matrix(ytest, y_pred))
confmatrx.head()
# Out:
# accuracy 	 0.7366666666666667
#      0    1    2
# 0  151   49    0
# 1   49  131   20
# 2    0   40  160

# %% [markdown]
# 7.Combine the 3 stacking classifiers
# ==============

# %%
lr2_3 = LogisticRegression()
temprf_3=RandomForestClassifier(n_estimators=500, random_state=42)
temprf2_3=RandomForestClassifier()
tempsvC_3= SVC()

estimators_3 = [
    sclf2,  stackingc_5,stackingc_12    

]
stackingc_3 = StackingClassifier(
    classifiers=estimators_3, 
    meta_classifier=temprf2_3,
    verbose=2 
)

# %%
stackingc_3.fit(xtrain,ytrain)

# %%
y_pred = stackingc_3.predict((xtest))

print("accuracy \t", m.accuracy_score(ytest, y_pred))
confmatrx = pd.DataFrame(m.confusion_matrix(ytest, y_pred))
confmatrx.head()

# %%
# from sklearn.pipeline import make_pipeline
# from mlxtend.feature_selection import ColumnSelector
# from mlxtend.classifier import StackingCVClassifier

# pipe1 = make_pipeline(rf)
# pipe11 = make_pipeline( xgb_model)
# pipe12 = make_pipeline( SVC_clf)
# pipe13 = make_pipeline( LogisticRegression())

# pipe2 = make_pipeline(ColumnSelector(cols=(0,1,2,9,10)), rf )
# pipe21 = make_pipeline(ColumnSelector(cols=(0,1,2,9,10)), xgb_model )
# pipe22 = make_pipeline(ColumnSelector(cols=(0,1,2,9,10)), SVC_clf )
# pipe22 = make_pipeline(ColumnSelector(cols=(0,1,2,9,10)), LogisticRegression() )



# sclf1 = StackingCVClassifier(classifiers=[    pipe1,    pipe11,    pipe12 ],
#                            meta_classifier=LogisticRegression(),random_state=42)

# sclf2 = StackingCVClassifier(classifiers=[    pipe2,    pipe21,    pipe22],
#                            meta_classifier=LogisticRegression(),random_state=42)

# sclf = StackingCVClassifier(classifiers=[
#    sclf1,sclf2
# ], 
#                             meta_classifier=LogisticRegression(),
#                             random_state=42)
